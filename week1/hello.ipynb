# %%
print('Hello')
# Out:
# Hello

# %%
x = 10
print(x, type(x))
# Out:
# 10 <class 'int'>

# %%
pi = 3.14
print(pi, type(pi))
# Out:
# 3.14 <class 'float'>

# %%
s = 'Hello World'
print(s, type(s))
# Out:
# Hello World <class 'str'>

# %%
b = True
print(b, type(b))
# Out:
# True <class 'bool'>

# %%
my_list = [1, 2, 3, 4, 5]
print(my_list, type(my_list))
# Out:
# [1, 2, 3, 4, 5] <class 'list'>

# %%
my_list = [1, '2', 3.0, True]
print(my_list, type(my_list))
# Out:
# [1, '2', 3.0, True] <class 'list'>

# %%
print(my_list[0])
# Out:
# 1

# %%
my_dict = {'hello': 'xin chào',
          'goodbye': 'tạm biệt',
          'thank you': 'cảm ơn'}
print(my_dict, type(my_dict))
print(my_dict['hello'])
# Out:
# {'hello': 'xin chào', 'goodbye': 'tạm biệt', 'thank you': 'cảm ơn'} <class 'dict'>
# xin chào

# %%
a = 10
print(type(a))

a = 10.0
print(type(a))

a = '10'
print(type(a))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
